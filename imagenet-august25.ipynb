# %%
import numpy as np
from numpy import full
from prediction import make_predictions
import os

# %% [markdown]
# ## loading and creating image arrays

# %%
image_stack = np.load('image_stacks/image_stack(8-14-2025).npy')

# %%
image_stack.shape
# Out:
# (100, 144, 256)

# %%
gray_frames = np.full((10, 144, 256), 128)

# %%
image_stack = np.concatenate((gray_frames, image_stack), 0)
print('image stack shape: ', image_stack.shape)
# Out:
# image stack shape:  (110, 144, 256)

# %% [markdown]
# ## test predictions

# %%
"""
Assumptions
1. scans.csv must be in same directory
2. microns_area_labels.csv is in same directory
"""

# note that image input must have shape (x, 144, 256) where x is the number of frames 
frames = full(shape = (5,144,256), fill_value = 128)

a, b, c, d = make_predictions('dynamic', frames, 3, [[4,7]], noise_seeds = 2, num_frames = 3)

ano, bno, cno, dno = make_predictions('no noise', frames, 100, [[4,7]], noise_seeds = 2, num_frames = 3)

print('dynamic to no noise: ', np.unique(a == ano, return_counts = True))
print(f'max of dynamic: {np.max(a):.3f}; max of no noise: {np.max(ano):.3f}\n')

a, b, c, d = make_predictions('dynamic', frames, 100, [[4,7]], noise_seeds = 2, num_frames = 3, stochastic_bin_param = True)

ano, bno, cno, dno = make_predictions('constant', frames, 100, [[4,7]], noise_seeds = 2, num_frames = 3, stochastic_bin_param = True)

print('two stoch bin: ', np.unique(a == ano, return_counts = True))
print(f'max of first: {np.max(a):.3f}; max of no second" {np.max(ano):.3f}')
# Out:
# dynamic to no noise:  (array([False,  True]), array([74929,     1]))
# max of dynamic: 17.392; max of no noise: 17.385
#
# two stoch bin:  (array([False]), array([74930]))
# max of first: 11.824; max of no second" 11.433

# %% [markdown]
# ## collecting predictions

# %% [markdown]
# per meeting with ralf only collect dynamic stochastic binarization for now

# %%
stoch_bin_sum, stoch_bin_mean, stoch_bin_var, stoch_bin_labels = make_predictions(noise_type = 'dynamic', images = test_image, sigma = 0, 
                                                                                  scans = [[4,7]], stochastic_bin_param = True)

# %% [markdown]
# ## collecting predictions, store per image

# %%
image_stack.shape
# Out:
# (110, 144, 256)

# %%
test_image = image_stack[0].reshape(1, 144, 256)

# %% [markdown]
# execute one at a time, likely not going to run while computer asleep
#
# note that images seem to take longer than gray frames

# %%
def store_prediction(image_i: int):
    image = image_stack[image_i].reshape(1, 144, 256)
    sum_arr, mean_arr, var_arr, label_arr = make_predictions(noise_type = 'dynamic', images = image, sigma = 0, 
                                                                                    scans = [[4,7]], stochastic_bin_param = True)
    save_path = f'predictions/8-27-2025/image{image_i}'
    os.mkdir(save_path)
    np.save(f'{save_path}/sum_arr_image{image_i}', sum_arr)
    np.save(f'{save_path}/mean_arr_image{image_i}', mean_arr)
    np.save(f'{save_path}/var_arr_image{image_i}', var_arr)
    np.save(f'{save_path}/label_arr_image{image_i}', label_arr)
    print(f'---image {image_i} predictions stored---')
    return

# %% [markdown]
# #### collecting responses in single cells

# %% [markdown]
# not sure why this executes much quicker than regular for loop

# %%
id = 54

# %%
store_prediction(id)
id+=1
# Out:
# ---image 54 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 55 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 56 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 57 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 58 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 59 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 60 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 61 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 62 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 63 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 64 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 65 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 66 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 67 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 68 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 69 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 70 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 71 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 72 predictions stored---

# %%
store_prediction(id)
id+=1
# Out:
# ---image 73 predictions stored---

# %%
print('id is equal to: ',id)
# Out:
# id is equal to:  74
