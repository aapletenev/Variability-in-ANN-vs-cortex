# %%
import numpy as np
from numpy import full
from prediction import make_predictions

# %% [markdown]
# ## loading and creating image arrays

# %%
image_stack = np.load('image_stacks/image_stack(8-14-2025).npy')

# %%
image_stack.shape
# Out:
# (100, 144, 256)

# %%
gray_frames = np.full((10, 144, 256), 128)

# %%
image_stack = np.concatenate((gray_frames, image_stack), 0)
print('image stack shape: ', image_stack.shape)
# Out:
# image stack shape:  (110, 144, 256)

# %% [markdown]
# ## test predictions

# %%
"""
Assumptions
1. scans.csv must be in same directory
2. microns_area_labels.csv is in same directory
"""

# note that image input must have shape (x, 144, 256) where x is the number of frames 
frames = full(shape = (5,144,256), fill_value = 128)

a, b, c, d = make_predictions('dynamic', frames, 3, [[4,7]], noise_seeds = 2, num_frames = 3)

ano, bno, cno, dno = make_predictions('no noise', frames, 100, [[4,7]], noise_seeds = 2, num_frames = 3)

print('dynamic to no noise: ', np.unique(a == ano, return_counts = True))
print(f'max of dynamic: {np.max(a):.3f}; max of no noise: {np.max(ano):.3f}\n')

a, b, c, d = make_predictions('dynamic', frames, 100, [[4,7]], noise_seeds = 2, num_frames = 3, stochastic_bin_param = True)

ano, bno, cno, dno = make_predictions('constant', frames, 100, [[4,7]], noise_seeds = 2, num_frames = 3, stochastic_bin_param = True)

print('two stoch bin: ', np.unique(a == ano, return_counts = True))
print(f'max of first: {np.max(a):.3f}; max of no second" {np.max(ano):.3f}')
# Out:
# dynamic to no noise:  (array([False,  True]), array([74929,     1]))
# max of dynamic: 17.392; max of no noise: 17.385
#
# two stoch bin:  (array([False]), array([74930]))
# max of first: 11.824; max of no second" 11.433

# %% [markdown]
# ## collecting predictions

# %% [markdown]
# per meeting with ralf only collect dynamic stochastic binarization for now

# %%
stoch_bin_sum, stoch_bin_mean, stoch_bin_var, stoch_bin_labels = make_predictions(noise_type = 'dynamic', images = image_stack, sigma = 0, 
                                                                                  scans = [[4,7]], stochastic_bin_param = True,
                                                                                  noise_seeds = 100, num_frames = 15)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 stoch_bin_sum, stoch_bin_mean, stoch_bin_var, stoch_bin_labels = make_predictions(noise_type = 'dynamic', images = image_stack, sigma = 0,
#       2                                                                                   scans = [[4,7]], stochastic_bin_param = True,
#       3                                                                                   noise_seeds = 100, num_frames = 15)
#
# File c:\Users\joshf\OneDrive\GitHub\fnn-haefner\prediction.py:85, in make_predictions(noise_type, images, sigma, scans, stochastic_bin_param, noise_seeds, num_frames)
#      82     predict_stack = np.repeat(images[i][np.newaxis, :], num_frames, axis=0) # need to broadcast?
#      83     return noise_iterations(models_list, ids_list, noise_type, noise_seeds, predict_stack, sigma, scans, stochastic_bin_param, num_frames)
# ---> 85 final_array = np.array([process_image(i) for i in range(len(images))])
#      87 final_stack_sum = np.sum(final_array, axis=2)
#      88 final_mean, final_var = np.mean(final_stack_sum, axis=1), np.var(final_stack_sum, axis=1)
#
# File c:\Users\joshf\OneDrive\GitHub\fnn-haefner\prediction.py:83, in make_predictions.<locals>.process_image(i)
#      81 def process_image(i: int):
#      82     predict_stack = np.repeat(images[i][np.newaxis, :], num_frames, axis=0) # need to broadcast?
# ---> 83     return noise_iterations(models_list, ids_list, noise_type, noise_seeds, predict_stack, sigma, scans, stochastic_bin_param, num_frames)
#
# File c:\Users\joshf\OneDrive\GitHub\fnn-haefner\noise_seeds.py:118, in noise_iterations(model_list, id_list, noise_type, noise_seeds, image, sigma, scans, stochastic_bin_param, num_frames)
#     115     else: raise ValueError ('---Enter "true" or "false" for stchastic_bin_param.---')
#     117 for i in range(noise_seeds):
# --> 118     result = process_noise_seed(noise_type, image)
#     119     noise_results[i] = result
#     120 # store result as array in directory
#     121 # delete previous result from memory, re run
#
# File c:\Users\joshf\OneDrive\GitHub\fnn-haefner\noise_seeds.py:103, in noise_iterations.<locals>.process_noise_seed(noise_type, image)
#     100         return
#     102     for model, ids in zip(model_list, id_list):
# --> 103         prediction = model.predict(new_image)
#     104     return prediction
#     106 elif stochastic_bin_param == False:  # case: no stochastic bin.
#
# File c:\Users\joshf\OneDrive\GitHub\fnn-haefner\fnn\model\networks.py:597, in Visual.predict(self, stimuli, perspectives, modulations)
#     577 """
#     578 Parameters
#     579 ----------
#    (...)
#     594     [T, U] (singular input) | [T, N, U] (batch input) -- dtype=float
#     595 """
#     596 response = self.generate_response(stimuli, perspectives, modulations)
# --> 597 return np.array([*response])
#
# File c:\Users\joshf\OneDrive\GitHub\fnn-haefner\fnn\model\networks.py:492, in Visual.generate_response(self, stimuli, perspectives, modulations, training, reset)
#     486 for stimulus, perspective, modulation in zip(
#     487     stimuli, perspectives, modulations
#     488 ):
#     490     *tensors, squeeze = self.to_tensor(stimulus, perspective, modulation)
# --> 492     response = self(*tensors)
#     493     if squeeze:
#     494         response = response.squeeze(0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\joshf\OneDrive\GitHub\fnn-haefner\fnn\model\networks.py:342, in Visual.forward(self, stimulus, perspective, modulation, stream, periphery)
#     322 def forward(self, stimulus, perspective, modulation, stream=None, periphery="dark"):
#     323     """
#     324     Parameters
#     325     ----------
#    (...)
#     340         [N, U] -- response frame
#     341     """
# --> 342     r = self._raw(
#     343         stimulus=stimulus,
#     344         perspective=perspective,
#     345         modulation=modulation,
#     346         stream=stream,
#     347         periphery=periphery,
#     348     )
#     349     return self.unit(readout=r)
#
# File c:\Users\joshf\OneDrive\GitHub\fnn-haefner\fnn\model\networks.py:308, in Visual._raw(self, stimulus, perspective, modulation, stream, periphery)
#     302     modulation = modulation.repeat(1, self.streams)
#     304 modulation = self.modulation(
#     305     modulation=modulation,
#     306     stream=stream,
#     307 )
# --> 308 core = self.core(
#     309     perspective=perspective,
#     310     modulation=modulation,
#     311     stream=stream,
#     312 )
#     313 readout = self.readout(
#     314     core=core,
#     315     stream=stream,
#     316 )
#     317 if stream is None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\joshf\OneDrive\GitHub\fnn-haefner\fnn\model\cores.py:137, in FeedforwardRecurrent.forward(self, perspective, modulation, stream)
#     135 f = self.feedforward([perspective], stream=stream)
#     136 m = modulation[:, :, None, None]
# --> 137 r = self.recurrent([f, m], stream=stream)
#     138 return r
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\joshf\OneDrive\GitHub\fnn-haefner\fnn\model\recurrents.py:548, in CvtLstm.forward(self, x, stream)
#     545 N, _, H, W = z.shape
#     546 HW = H * W
# --> 548 q = self.proj_q(z, stream=stream).view(N, S, self.groups, self.group_channels, HW)
#     549 k = self.proj_k(z, stream=stream).view(N, S, self.groups, self.group_channels, HW)
#     550 v = self.proj_v(z, stream=stream).view(N, S, self.groups, self.group_channels, HW)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\joshf\OneDrive\GitHub\fnn-haefner\fnn\model\elements.py:325, in Conv.forward(self, x, stream)
#     322     groups = self.in_groups
#     323     bias = self.biases[stream].flatten() if self.bias else None
# --> 325 y = nn.functional.conv3d(input=x, weight=weight, bias=bias, groups=groups, stride=self.stride)
#     326 return y.squeeze(dim=2)
#
# KeyboardInterrupt:
