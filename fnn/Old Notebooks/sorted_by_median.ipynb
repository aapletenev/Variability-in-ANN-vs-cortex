# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
from scipy.optimize import curve_fit
import sympy
from sympy import symbols, diff
from visualizations import lineplots_4x4, smooth_func
from processing import filter_region
from datetime import datetime
import glasbey

# %% [markdown]
# # load prediction arrays, create array objects

# %%
folder_path = 'predictions/8-27-2025/'

# %%
folders = [folder for folder in os.listdir(folder_path)]
print('len of folders: ', len(folders))
# Out:
# len of folders:  110

# %%
test_sum = np.load(f'{folder_path}image0/sum_arr_image0.npy')
print('test_sum shape: ', test_sum.shape)
# Out:
# test_sum shape:  (1, 100, 7493)

# %%
def load_arrs(arr_type: str):
    if arr_type not in ['sum', 'mean', 'var', 'label']: raise ValueError ('---Insert "sum" or "mean" "var" or "label" as input---')
    return_arr = np.empty((110, 100, 7493)) if arr_type == 'sum' else np.empty((110, 7493))
    for arr_index in range(110):
        arr_temp = np.load(f'{folder_path}image{arr_index}/{arr_type}_arr_image{arr_index}.npy')
        return_arr[arr_index] = arr_temp
    return return_arr

# %%
sum_arr = load_arrs('sum')
mean_arr = load_arrs('mean')
var_arr = load_arrs('var')
label_arr = load_arrs('label')

# %%
print(f'sum shape: {sum_arr.shape}; mean shape: {mean_arr.shape}; var shape: {var_arr.shape}')
# Out:
# sum shape: (110, 100, 7493); mean shape: (110, 7493); var shape: (110, 7493)

# %%
np.unique(mean_arr == var_arr, return_counts = True) # ensure we are returning different arrays
# Out:
# (array([False]), array([824230]))

# %% [markdown]
# # get mean and var arrays from V1
# filtering done as well

# %% [markdown]
# get region 1 here

# %%
mean_v1 = filter_region(1, label_arr, mean_arr)
var_v1 = filter_region(1, label_arr, var_arr)

# %%
print(f'mean shape: {mean_v1.shape}, var shape: {var_v1.shape}')
# Out:
# mean shape: (110, 5312), var shape: (110, 5312)

# %% [markdown]
# ### remove anything above 200 spikes/sec

# %%
mean_v1_removed = remove_rate(mean_v1, 200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mean_v1_removed = remove_rate(mean_v1, 200)
#
# NameError: name 'remove_rate' is not defined

# %%
print('mean shape:', mean_v1_removed.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print('mean shape:', mean_v1_removed.shape)
#
# NameError: name 'mean_v1_removed' is not defined

# %%
np.unique(np.isnan(mean_v1_removed), return_counts = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 np.unique(np.isnan(mean_v1_removed), return_counts = True)
#
# NameError: name 'mean_v1_removed' is not defined

# %%
var_v1_removed = np.where(np.isnan(mean_v1_removed), mean_v1_removed, var_v1)

# %%
print('var shape:', var_v1_removed.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print('var shape:', var_v1_removed.shape)
#
# NameError: name 'var_v1_removed' is not defined

# %%
np.unique(np.isnan(var_v1_removed), return_counts = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 np.unique(np.isnan(var_v1_removed), return_counts = True)
#
# NameError: name 'var_v1_removed' is not defined

# %%
test_neuron = 250

# %%
mean_v1_removed[..., test_neuron]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 mean_v1_removed[..., test_neuron]
#
# NameError: name 'mean_v1_removed' is not defined

# %%
var_v1_removed[..., test_neuron]

# %% [markdown]
# ### get indices to sort

# %%
print(f'unique counts for mean_arr:', np.unique(np.isnan(mean_v1_removed), return_counts = True))
print(f'unique counts for var_arr:', np.unique(np.isnan(var_v1_removed), return_counts = True))
print('ensure that we have the same counts for both arrays')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(f'unique counts for mean_arr:', np.unique(np.isnan(mean_v1_removed), return_counts = True))
#       2 print(f'unique counts for var_arr:', np.unique(np.isnan(var_v1_removed), return_counts = True))
#       3 print('ensure that we have the same counts for both arrays')
#
# NameError: name 'mean_v1_removed' is not defined

# %%
# run this when wanting to use array with removed values
med_arr = np.nanmedian(mean_v1_removed, axis = 0)
med_arr.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # run this when wanting to use array with removed values
# ----> 2 med_arr = np.nanmedian(mean_v1_removed, axis = 0)
#       3 med_arr.shape
#
# NameError: name 'mean_v1_removed' is not defined

# %%
# run this when wanting to use array WITHOUT removed values
med_arr = np.nanmedian(mean_v1, axis = 0)
med_arr.shape
# Out:
# (5312,)

# %%
for med_num in med_arr: print(med_num)
# Out:
# 3.974802479445934
# 2.3593027226626875
# 2.7362008299678564
# 4.895194533690811
# 4.159150126725436
# 4.622548931688071
# 3.8818444656580686
# 15.556875945329667
# 9.279563005566597
# 3.154792268797755
# 11.045706401318311
# 11.950191638693212
# 16.900227708444
# 7.661633794233203
# 3.033049823902547
# 9.30696840506047
# 6.4384572376310825
# 6.047185640856624
# 11.741959682404996
# 2.748698159493506
# 5.376979952007532
# 32.34041048392653
# 9.889155838564038
# 4.96723891787231
# 4.9444513311982154
# 8.144839701205491
# 4.180796727389097
# 5.93926571033895
# 4.030008012950421
# 1.8058063982985915
# 7.819662510082125
# 2.6598577235639094
# 7.505931153818965
# 11.608138296306134
# 7.710553907603026
# 6.866133442521095
# 3.936572218760848
# 6.677319190055131
# 11.478807716667653
# 2.959846276640892
# 10.883172839507461
# 2.4146774923428893
# 8.800222636014222
# 8.321388820223511
# 6.008964550942183
# 3.6290272524207827
# 9.978706243857742
# 2.130712605416775
# 5.477237200438976
# 5.65389513477683
# 28.369277135431766
# 16.382591464966538
# 8.144303661733865
# 4.694839561488479
# 12.618418566584587
# 3.6645758013799785
# 7.116969480365515
# 3.0399235470592973
# 4.4918307106941935
# 9.178150705844164
# 7.406624312773347
# 1.0638498754426835
# 2.7983308615908027
# 4.999846949502826
# 7.147469306476414
# 7.967438695430756
# 2.8407472097873687
# 29.68010617032647
# 6.068646267056465
# 18.073277156949043
# 7.091924221515656
# 9.541999500989913
# 5.218171667978168
# 16.561411890164017
# 6.370536978263408
# 4.723250398430974
# 3.2026119977235794
# 3.069182835780084
# 3.8477532897517084
# 7.671821091100574
# 4.9287523579224946
# 2.5547573702782396
# 4.822956514805556
# 19.11733042038977
# 9.351878027245402
# 6.3323913280665876
# 25.009364853873848
# 16.16276842147112
# 4.446281566172837
# 7.729001609273255
# 3.397475239615887
# 9.896806007884443
# 0.9860292093083263
# 2.278626089692116
# 3.8215179630741476
# 2.1621475522965197
# 1.7701441778149456
# 1.939613599497825
# 0.6762277925014496
# 1.64191184990108
# 4.754599304366857
# 4.925448879674077
# 4.064946833662688
# 22.35346546024084
# 10.149058954790235
# 7.3587687929719685
# 9.458242885023356
# 10.160261504948139
# 13.205895188748837
# 5.851851641908288
# 7.150880328193306
# 7.35698094420135
# 3.6447368962690234
# 5.354897513315082
# 59.469200870543716
# 4.076176152303814
# 2.675669245235622
# 1.6938603123277425
# 9.872398028299212
# 3.182569002658129
# 15.420881481692195
# 17.055942525565627
# 7.982673982605338
# 3.925875018760562
# 4.436395468264818
# 1.3223136181756854
# 13.334124552309513
# 14.486134645640849
# 14.6667631419003
# 10.743204119950533
# 6.819748129099607
# 9.51298931106925
# 4.894481758475304
# 2.5832300806045536
# 2.0453537849336865
# 4.254232052918523
# 13.459408798068761
# 6.9533812985196715
# 2.525327194202691
# 14.248613237291574
# 2.949190239235759
# 10.739902477115393
# 8.572995571792125
# 3.605017891600728
# 4.6609655538946395
# 2.9903092294186355
# 2.5217116532847283
# 6.120912250727415
# 9.898291187584402
# 7.682422467693687
# 9.06924934193492
# 2.9120561209321023
# 3.1542689113691447
# 2.512375639639795
# 9.385019270181656
# 7.419780412614346
# 12.552180079966783
# 1.3057519552856682
# 3.5343391901254657
# 3.6365442977845666
# 5.488009246364236
# 29.36364624697715
# 10.333603004105388
# 4.501065539717674
# 4.480225449278951
# 3.896755550354719
# 1.6567087029665708
# 4.997997911572456
# 17.27106842547655
# 5.657783119305968
# 4.937914907597006
# 2.3266980469971896
# 9.572955593168736
# 0.9715412314236165
# 2.877144624274224
# 19.139513407498598
# 4.343950258940458
# 2.34045990023762
# 5.16964599519968
# 5.463455758616329
# 7.55554812155664
# 4.493607893753797
# 11.116116598248482
# 6.32082066334784
# 2.313146142922342
# 4.344530996084213
# 5.570986253321172
# 2.6810462086647746

# %%
sort_indices = np.argsort(med_arr)[::-1]

# %%
len(sort_indices)
# Out:
# 5312

# %%
# use this for when we remove above x rate
mean_v1_sorted = mean_v1_removed[..., sort_indices]
var_v1_sorted = var_v1_removed[..., sort_indices]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # use this for when we remove above x rate
# ----> 2 mean_v1_sorted = mean_v1_removed[..., sort_indices]
#       3 var_v1_sorted = var_v1_removed[..., sort_indices]
#
# NameError: name 'mean_v1_removed' is not defined

# %%
# use this OTHERWISE
mean_v1_sorted = mean_v1[..., sort_indices]
var_v1_sorted = var_v1[..., sort_indices]

# %%
for neuron in range(mean_v1_sorted.shape[1]):
    print(np.nanmedian(mean_v1_sorted[..., neuron]))
# Out:
# 171.38495882749558
# 101.54519626885653
# 94.49687044247985
# 89.33933751612902
# 88.69355226486921
# 73.27105030372739
# 71.10828003756703
# 67.6045885861665
# 61.959355877041816
# 61.37937041044235
# 59.469200870543716
# 58.768830648139115
# 56.09253716938198
# 55.89795800149441
# 55.2687453892082
# 54.079851799756284
# 52.80393466621638
# 50.72823161497712
# 49.91323401540518
# 48.73878699541092
# 48.383089814931154
# 48.26628786623478
# 47.50984756365418
# 46.57595436573028
# 46.5336930051446
# 46.17690957084298
# 46.159384136572484
# 44.89896320953965
# 44.79695196434855
# 44.009024114906794
# 43.796159941852096
# 43.42643831774592
# 42.952280337810514
# 41.65624650403858
# 41.60993857957423
# 40.832148746848105
# 40.389421806037426
# 40.24494306921959
# 39.53064896084368
# 38.40419747754932
# 38.23513535104692
# 1.1958756379783153
# 1.1883511360548438
# 1.178845828101039
# 1.1760108780674636
# 1.1746799493953586
# 1.1725931541249155
# 1.168160616271198
# 1.1667613488249482
# 1.1657093976438047
# 1.1592107781767846
# 1.1560516322776675
# 1.1537379790749402
# 1.1480630234628917
# 1.1470519891753792
# 1.1455027539469302
# 1.1448222143389284
# 1.1332032005302608
# 1.1324153234437109
# 1.1321941289491952
# 1.130252358065918
# 1.1288818647153676
# 1.1287384652160108
# 1.1240629307366907
# 1.1214111295714975
# 1.1190814372524618
# 1.1146663325000554
# 1.1076896465942263
# 1.1075152060762048
# 1.104583496088162
# 1.1011229433398695
# 1.0960330520384014
# 1.085130534619093
# 1.0794894569646567
# 1.0785920624481515
# 1.0687717498280107
# 1.0638498754426835
# 1.0596628279983997
# 1.0566732330340893
# 1.0457735945470632
# 1.0379870797973125
# 1.035966304782778
# 1.035652707349509
# 1.0318991365469992
# 1.0304387338086962
# 1.0299131536856292
# 1.0273339572176337
# 1.0266338201425969
# 1.0265678581222892
# 1.0255331346206367
# 1.0244837972894312
# 1.0233879819698632
# 1.017616749908775
# 1.0169147433619945
# 1.0165681312046946
# 1.0129146916791796
# 1.008845869116485
# 1.0084101081453265
# 1.0028129828628152
# 0.9949315171502531
# 0.9938889603503049
# 0.9860292093083263
# 0.9753954288829119
# 0.9744285888224841
# 0.9715412314236165
# 0.9641505992971361
# 0.9629732673056424
# 0.9601160344667733
# 0.9497618619073183
# 0.9488385469093918
# 0.9466046596318484
# 0.9334122769907116
# 0.9302922728657723
# 0.9095165310893207
# 0.9031070512160659
# 0.892387421540916
# 0.8889939837809653
# 0.8887575700320303
# 0.888747585611418
# 0.8643300201371311
# 0.8630470992065966
# 0.8628986303694546
# 0.8582748480699957
# 0.8575521110650152
# 0.8517363297753036
# 0.8465537440963089
# 0.8446001976728439
# 0.8374036437366157
# 0.8358605632465332
# 0.8341732641961426
# 0.8230074002780021
# 0.8188800965342671
# 0.8128911041561514
# 0.8042225840548054
# 0.7919243014138191
# 0.7643156650569289
# 0.7635096873994917
# 0.741296833944507
# 0.7363047949783504
# 0.7287069324217736
# 0.717217937540263
# 0.7171828189399093
# 0.6942969448398799
# 0.6776414902415127
# 0.6762277925014496
# 0.6732755566667765
# 0.6655844499357044
# 0.6325858870102092
# 0.6082424293644726
# 0.576933102584444
# 0.5446531110163778
# 0.4993486511241645
# 0.4953882051212713
# 0.45304603211116046
# 0.3972786303260364
# 0.23210810067947024

# %% [markdown]
# #### *note that this code works and has been checked properly up to here*

# %%
mean_v1_sorted[...,110]

# %%
var_v1_sorted[..., 110]

# %%
lineplots_4x4('test', mean_v1_sorted, var_v1_sorted)

# %%
neuron = 0
mean_masked = mean_v1_sorted
var_masked = var_v1_sorted

mask = ~np.isnan(mean_masked[..., neuron]) & ~np.isnan(var_masked[..., neuron])

x_nonan = mean_masked[..., neuron][mask]
y_nonan = var_masked[..., neuron][mask]

params, covariance = curve_fit(smooth_func, x_nonan, y_nonan, maxfev = 1_000_000, p0 = [1,0.001])
x_max = np.max(x_nonan)

y_pred = smooth_func(np.linspace(0, x_max, 1000), params[0], params[1])
plt.plot(np.linspace(0, x_max, 1000), y_pred, color='r', label='smooth function regression', alpha=0.7)
#plt.text(0.01, 0.99, f'neuron: {neuron+1}\nm: {params[0]:.3f}\nb: {params[1]:.3f}', verticalalignment = 'top', horizontalalignment = 'left')

plt.scatter(x_nonan, y_nonan)
plt.show()

# %% [markdown]
# # adjusting scatter plot

# %%
# per ralf's comments, play around with scaling

def lineplots_4x4(main_title, mean_masked, var_masked, neurons = [i for i in range(16)], savefig = False):
    """
    Parameters
    ----------
    main_title: str
        title for plot
    mean_masked: np.array
        mean array of data
    var_masked: np.array
        array of variance data
    neurons: list (ints)
        list of neurons to plot, defualts to first 16
    savefig: bool 
        whether or not to save figure to computer
    Returns
    -------
    plt.show()
        scatter plots with regression shown
    """
    fig, axes = plt.subplots(4, 4, figsize=(10, 8), sharex=False, sharey=False)
    fig.text(0.5, 1.04, main_title, ha='center', va='top', fontsize=14, fontweight = 'bold', bbox=dict(facecolor='white'))

    for id, neuron in enumerate(neurons):
        i, j = divmod(id, 4)
        ax = axes[i, j]
        
        ax.scatter(mean_masked[..., neuron][:10], var_masked[..., neuron][:10], color = 'black', alpha = 0.5, marker = '.', label = 'predicted response (gray frames)')
        ax.scatter(mean_masked[..., neuron][10:], var_masked[..., neuron][10:], color = 'b', alpha = 0.3, marker = '.', label = 'predicted response (imagenet)')

        # regression
        mask = ~np.isnan(mean_masked[..., neuron]) & ~np.isnan(var_masked[..., neuron])
        x_nonan = mean_masked[..., neuron][mask]
        y_nonan = var_masked[..., neuron][mask]

        params, covariance = curve_fit(smooth_func, x_nonan, y_nonan, maxfev = 1_000_000, p0 = [1, 0.001])
        x_min, x_max = ax.get_xlim()
        y_pred = smooth_func(np.linspace(0, x_max, 1000), params[0], params[1])
        ax.plot(np.linspace(0, x_max, 1000), y_pred, color='r', label='smooth function regression', alpha=0.7)
        ax.text(0.01, 0.99, f'neuron: {neuron+1}\nm: {params[0]:.3f}\nb: {params[1]:.3f}', verticalalignment = 'top', horizontalalignment = 'left', 
                transform = ax.transAxes)
        if i == 3: ax.set_xlabel('Mean Predicted\nSpike Count')
        if j == 0: ax.set_ylabel('Variance in\nPredicted Spike Count')

        #ax.set_xlim(0, min(np.max(mean_masked)/3, 200)) # how to handle outliers
        
    handles, labels = axes[0, 0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='upper right', bbox_to_anchor=(1.02, 1.08), ncol=1)    
    plt.tight_layout()
    if savefig: 
        try:
            date = datetime.now()
            file_date = f'({str(date.month)}-{str(date.day)}-{str(date.year)})'
            path_name = f'{main_title}_{file_date}.pdf'
            plt.savefig(os.path.join(os.getcwd(), f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', path_name), 
                        bbox_inches = 'tight', pad_inches = 0.3)
        except FileNotFoundError:
            os.makedirs(f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', exist_ok = True)
            plt.savefig(os.path.join(os.getcwd(), f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', path_name),
                        bbox_inches = 'tight', pad_inches = 0.3)
            plt.close()
    else: 
        plt.show()

# %%
lineplots_4x4('Sorted by Highest Median Descending\nNeurons 48-64', mean_v1_sorted, var_v1_sorted, neurons = [i for i in range(48, 64)])

# %% [markdown]
# # plot in log space

# %%
def lineplots_4x4(main_title, mean_masked, var_masked, neurons = [i for i in range(16)], savefig = False):
    """
    Parameters
    ----------
    main_title: str
        title for plot
    mean_masked: np.array
        mean array of data
    var_masked: np.array
        array of variance data
    neurons: list (ints)
        list of neurons to plot, defualts to first 16
    savefig: bool 
        whether or not to save figure to computer
    Returns
    -------
    plt.show()
        scatter plots with regression shown
    """
    fig, axes = plt.subplots(4, 4, figsize=(10, 8), sharex=False, sharey=False)
    fig.text(0.5, 1.04, main_title, ha='center', va='top', fontsize=14, fontweight = 'bold', bbox=dict(facecolor='white'))

    for id, neuron in enumerate(neurons):
        i, j = divmod(id, 4)
        ax = axes[i, j]
        
        ax.scatter(mean_masked[..., neuron][:10], var_masked[..., neuron][:10], color = 'black', alpha = 0.5, marker = '.', label = 'predicted response (gray frames)')
        ax.scatter(mean_masked[..., neuron][10:], var_masked[..., neuron][10:], color = 'b', alpha = 0.3, marker = '.', label = 'predicted response (imagenet)')

        # regression
        mask = ~np.isnan(mean_masked[..., neuron])
        x_nonan = mean_masked[..., neuron][mask]
        y_nonan = var_masked[..., neuron][mask]

        params, covariance = curve_fit(smooth_func, x_nonan, y_nonan, maxfev = 1_000_000, p0 = [1, .001])
        y_pred = smooth_func(np.linspace(0, np.max(x_nonan), 100), params[0], params[1])
        ax.plot(np.linspace(0, np.max(x_nonan), 100), y_pred, color = 'r', label = 'smooth function regression', alpha = 0.7)
        
        ax.text(0.01, 0.99, f'neuron: {neuron+1}\nm: {params[0]:.3f}\nb: {params[1]:.3f}', verticalalignment = 'top', horizontalalignment = 'left', 
                transform = ax.transAxes)
        if i == 3: ax.set_xlabel('Mean Predicted\nSpike Count')
        if j == 0: ax.set_ylabel('Variance in\nPredicted Spike Count')

        #ax.set_xlim(0, min(np.max(mean_masked)/3, 200)) # how to handle outliers

        ax.set_xscale('log')
        ax.set_yscale('log')
    handles, labels = axes[0, 0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='upper right', bbox_to_anchor=(1.02, 1.08), ncol=1)    
    plt.tight_layout()
    if savefig: 
        try:
            date = datetime.now()
            file_date = f'({str(date.month)}-{str(date.day)}-{str(date.year)})'
            path_name = f'{main_title}_{file_date}.pdf'
            plt.savefig(os.path.join(os.getcwd(), f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', path_name), 
                        bbox_inches = 'tight', pad_inches = 0.3)
        except FileNotFoundError:
            os.makedirs(f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', exist_ok = True)
            plt.savefig(os.path.join(os.getcwd(), f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', path_name),
                        bbox_inches = 'tight', pad_inches = 0.3)
            plt.close()
    else: 
        plt.show()

# %% [markdown]
# # final function (september 29th)

# %%
def lineplots_4x4(main_title, mean_masked, var_masked, neurons = [i for i in range(16)], savefig = False, logspace = False):
    """
    Parameters
    ----------
    main_title: str
        title for plot
    mean_masked: np.array
        mean array of data
    var_masked: np.array
        array of variance data
    neurons: list (ints)
        list of neurons to plot, defualts to first 16
    savefig: bool 
        whether or not to save figure to computer
    Returns
    -------
    plt.show()
        scatter plots with regression shown
    """
    fig, axes = plt.subplots(4, 4, figsize=(10, 8), sharex=False, sharey=False)
    fig.text(0.5, 1.04, main_title, ha='center', va='top', fontsize=14, fontweight = 'bold', bbox=dict(facecolor='white'))

    for id, neuron in enumerate(neurons):
        i, j = divmod(id, 4)
        ax = axes[i, j]
        
        ax.scatter(mean_masked[..., neuron][:10], var_masked[..., neuron][:10], color = 'black', alpha = 0.5, marker = '.', label = 'predicted response (gray frames)')
        ax.scatter(mean_masked[..., neuron][10:], var_masked[..., neuron][10:], color = 'b', alpha = 0.3, marker = '.', label = 'predicted response (imagenet)')

        # regression
        mask = ~np.isnan(mean_masked[..., neuron])
        x_nonan = mean_masked[..., neuron][mask]
        y_nonan = var_masked[..., neuron][mask]

        params, covariance = curve_fit(smooth_func, x_nonan, y_nonan, maxfev = 1_000_000, p0 = [1, .001])
        y_pred = smooth_func(np.linspace(0, np.max(x_nonan), 100), params[0], params[1])
        ax.plot(np.linspace(0, np.max(x_nonan), 100), y_pred, color = 'r', label = 'smooth function regression', alpha = 0.7)
        
        ax.text(0.01, 0.99, f'neuron: {neuron+1}\nm: {params[0]:.3f}\nb: {params[1]:.3f}', verticalalignment = 'top', horizontalalignment = 'left', 
                transform = ax.transAxes)
        if i == 3: ax.set_xlabel('Mean Predicted\nSpike Count')
        if j == 0: ax.set_ylabel('Variance in\nPredicted Spike Count')

        #ax.set_xlim(0, min(np.max(mean_masked)/3, 200)) # how to handle outliers

        if logspace: 
            ax.set_xscale('log')
            ax.set_yscale('log')
    handles, labels = axes[0, 0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='upper right', bbox_to_anchor=(1.02, 1.08), ncol=1)    
    plt.tight_layout()
    if savefig: 
        try:
            date = datetime.now()
            file_date = f'({str(date.month)}-{str(date.day)}-{str(date.year)})'
            path_name = f'{main_title}_{file_date}.pdf'
            plt.savefig(os.path.join(os.getcwd(), f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', path_name), 
                        bbox_inches = 'tight', pad_inches = 0.3)
        except FileNotFoundError:
            os.makedirs(f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', exist_ok = True)
            plt.savefig(os.path.join(os.getcwd(), f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', path_name),
                        bbox_inches = 'tight', pad_inches = 0.3)
            plt.close()
    else: 
        plt.show()

# %%
lineplots_4x4('Sorted by Highest Median Descending\nNeurons 1-16 (log space)', mean_v1_sorted, var_v1_sorted, neurons = [i for i in range(16)], logspace = True )

# %% [markdown]
# # a*x^b

# %%
def smooth_func(x, a, b): # used for regression in lineplots_4x4

    return a * x ** b

# %%
def lineplots_4x4(main_title, mean_masked, var_masked, neurons = [i for i in range(16)], savefig = False, logspace = False):
    """
    Parameters
    ----------
    main_title: str
        title for plot
    mean_masked: np.array
        mean array of data
    var_masked: np.array
        array of variance data
    neurons: list (ints)
        list of neurons to plot, defualts to first 16
    savefig: bool 
        whether or not to save figure to computer
    Returns
    -------
    plt.show()
        scatter plots with regression shown
    """
    fig, axes = plt.subplots(4, 4, figsize=(10, 8), sharex=False, sharey=False)
    fig.text(0.5, 1.04, main_title, ha='center', va='top', fontsize=14, fontweight = 'bold', bbox=dict(facecolor='white'))

    for id, neuron in enumerate(neurons):
        i, j = divmod(id, 4)
        ax = axes[i, j]
        
        ax.scatter(mean_masked[..., neuron][:10], var_masked[..., neuron][:10], color = 'black', alpha = 0.5, marker = '.', label = 'predicted response (gray frames)')
        ax.scatter(mean_masked[..., neuron][10:], var_masked[..., neuron][10:], color = 'b', alpha = 0.3, marker = '.', label = 'predicted response (imagenet)')

        # regression
        mask = ~np.isnan(mean_masked[..., neuron])
        x_nonan = mean_masked[..., neuron][mask]
        y_nonan = var_masked[..., neuron][mask]

        params, covariance = curve_fit(smooth_func, x_nonan, y_nonan, maxfev = 1_000_000, p0 = [1, .001])
        y_pred = smooth_func(np.linspace(0, np.max(x_nonan), 100), params[0], params[1])
        ax.plot(np.linspace(0, np.max(x_nonan), 100), y_pred, color = 'r', label = 'smooth function regression', alpha = 0.7)
        
        ax.text(0.01, 0.99, f'neuron: {neuron+1}\na: {params[0]:.3f}\nb: {params[1]:.3f}', verticalalignment = 'top', horizontalalignment = 'left', 
                transform = ax.transAxes)
        if i == 3: ax.set_xlabel('Mean Predicted\nSpike Count')
        if j == 0: ax.set_ylabel('Variance in\nPredicted Spike Count')

        #ax.set_xlim(0, min(np.max(mean_masked)/3, 200)) # how to handle outliers

        if logspace: 
            ax.set_xscale('log')
            ax.set_yscale('log')
    handles, labels = axes[0, 0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='upper right', bbox_to_anchor=(1.02, 1.08), ncol=1)    
    plt.tight_layout()
    if savefig: 
        try:
            date = datetime.now()
            file_date = f'({str(date.month)}-{str(date.day)}-{str(date.year)})'
            path_name = f'{main_title}_{file_date}.pdf'
            plt.savefig(os.path.join(os.getcwd(), f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', path_name), 
                        bbox_inches = 'tight', pad_inches = 0.3)
        except FileNotFoundError:
            os.makedirs(f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', exist_ok = True)
            plt.savefig(os.path.join(os.getcwd(), f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', path_name),
                        bbox_inches = 'tight', pad_inches = 0.3)
            plt.close()
    else: 
        plt.show()

# %%
lineplots_4x4('Sorted by Highest Median Descending\nNeurons 49-64 (a*x^b)', mean_v1_sorted, var_v1_sorted, neurons = [i for i in range(48, 64)], logspace = False )

# %%
lineplots_4x4('Sorted by Highest Median Descending\nNeurons 1-16 (log space, a*x^b)', mean_v1_sorted, var_v1_sorted, neurons = [i for i in range(16)], logspace = True )

# %% [markdown]
# # slope at x=100 vs median

# %%
x, m, b = symbols('x m b')

# %%
func_expr = (m / b) * (sympy.log(1 + sympy.exp(b * x)) - sympy.log(2) - (b * x) / 2)

# %%
func_prime = diff(func_expr, x)

# %%
answer = func_prime.subs({x: 50, m: 1, b: .001})
answer
# Out:
# 0.0124973964842103

# %%
m, b = np.polyfit(x_data, y_data, 1)

# Create the scatter plot
plt.scatter(x_data, y_data, label='Data Points')

# Plot the regression line
# The equation for a straight line is y = m*x + b
plt.plot(x_data, m * x_data + b, color='red', label='Regression Line')

# %%
def slope_median(main_title, mean_masked, var_masked, savefig = False, logspace = False, x_val = 100):
    """
    Parameters
    ----------
    main_title: str
        title for plot
    mean_masked: np.array
        mean array of data
    var_masked: np.array
        array of variance data
    neurons: list (ints)
        list of neurons to plot, defualts to first 16
    savefig: bool 
        whether or not to save figure to computer
    Returns
    -------
    plt.show()
        scatter plots with regression shown
    """
    medians = []
    slopes = []
    # define function
    x, m, b = symbols('x m b')
    func_expr = (m / b) * (sympy.log(1 + sympy.exp(b * x)) - sympy.log(2) - (b * x) / 2) # change function?
    func_prime = diff(func_expr, x)

    for neuron in range(mean_masked.shape[1]):
        
        mask = ~np.isnan(mean_masked[..., neuron])
        x_nonan = mean_masked[..., neuron][mask]
        y_nonan = var_masked[..., neuron][mask]

        params, covariance = curve_fit(smooth_func, x_nonan, y_nonan, maxfev = 1_000_000, p0 = [1, .001])

        # calculate slope at specified x_value
        slope = func_prime.subs({x: x_val, m: params[0], b: params[1]})

        medians.append(np.median(x_nonan))
        slopes.append(slope)
    medians, slopes = medians.astype(int), slopes.astype(int)
    plt.scatter(medians, slopes, alpha = 0.1)
    # regression
    m, b = np.polyfit(medians, slopes, 1)
    plt.plot(medians, m * medians + b, color='red', label='Regression Line')
    
    plt.title(f'{main_title}')
    plt.xlabel('median')
    plt.ylabel('slope')
    if logspace: 
        plt.xscale('log')
        plt.yscale('log')
    plt.tight_layout()
    if savefig: 
        try:
            date = datetime.now()
            file_date = f'({str(date.month)}-{str(date.day)}-{str(date.year)})'
            path_name = f'{main_title}_{file_date}.pdf'
            plt.savefig(os.path.join(os.getcwd(), f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', path_name), 
                        bbox_inches = 'tight', pad_inches = 0.3)
        except FileNotFoundError:
            os.makedirs(f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', exist_ok = True)
            plt.savefig(os.path.join(os.getcwd(), f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', path_name),
                        bbox_inches = 'tight', pad_inches = 0.3)
            plt.close()
    else: 
        plt.show()

# %%
slope_median('Slope for Original Smooth Function Against Median Value', mean_v1_sorted, var_v1_sorted, logspace = False)
# Out:
# c:\Users\joshf\OneDrive\GitHub\fnn-haefner\visualizations.py:780: RuntimeWarning: overflow encountered in exp
#   return (m / b) * (np.log1p(np.exp(b * x)) - np.log(2) - (b * x) / 2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 slope_median('Slope for Original Smooth Function Against Median Value', mean_v1_sorted, var_v1_sorted, logspace = False)
#
# Cell In[23], line 33, in slope_median(main_title, mean_masked, var_masked, savefig, logspace, x_val)
#      30 x_nonan = mean_masked[..., neuron][mask]
#      31 y_nonan = var_masked[..., neuron][mask]
# ---> 33 params, covariance = curve_fit(smooth_func, x_nonan, y_nonan, maxfev = 1_000_000, p0 = [1, .001])
#      35 # calculate slope at specified x_value
#      36 slope = func_prime.subs({x: x_val, m: params[0], b: params[1]})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\optimize\_minpack_py.py:1024, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1022 popt, pcov, infodict, errmsg, ier = res
#    1023 ysize = len(infodict['fvec'])
# -> 1024 cost = np.sum(infodict['fvec'] ** 2)
#    1025 if ier not in [1, 2, 3, 4]:
#    1026     raise RuntimeError("Optimal parameters not found: " + errmsg)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\fromnumeric.py:2250, in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2180     """
#    2181     Clip (limit) the values in an array.
#    2182
#    (...)
#    2245
#    2246     """
#    2247     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# -> 2250 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2251                     initial=None, where=None):
#    2252     return (a, out)
#    2255 @array_function_dispatch(_sum_dispatcher)
#    2256 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2257         initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:

# %%
def slope_median(main_title, mean_masked, var_masked, savefig = False, logspace = False, x_val = 100):
    """
    Parameters
    ----------
    main_title: str
        title for plot
    mean_masked: np.array
        mean array of data
    var_masked: np.array
        array of variance data
    neurons: list (ints)
        list of neurons to plot, defualts to first 16
    savefig: bool 
        whether or not to save figure to computer
    Returns
    -------
    plt.show()
        scatter plots with regression shown
    """
    medians = []
    slopes = []
    # define function
    x, m, b = symbols('x m b')
    func_expr = (m / b) * (sympy.log(1 + sympy.exp(b * x)) - sympy.log(2) - (b * x) / 2) # change function?
    func_prime = diff(func_expr, x)

    for neuron in range(mean_masked.shape[1]):
        
        mask = ~np.isnan(mean_masked[..., neuron])
        x_nonan = mean_masked[..., neuron][mask]
        y_nonan = var_masked[..., neuron][mask]

        params, covariance = curve_fit(smooth_func, x_nonan, y_nonan, maxfev = 1_000_000, p0 = [1, .001])

        # calculate slope at specified x_value
        slope = func_prime.subs({x: x_val, m: params[0], b: params[1]})

        medians.append(np.median(x_nonan))
        slopes.append(slope)
    
    plt.scatter(medians, slopes, alpha = 0.1, marker = '.')
    plt.title(f'{main_title}')
    plt.xlabel('median')
    plt.ylabel('slope')
    #plt.ylim(0, 25)
    #plt.xlim(0, 3)
    if logspace: 
        plt.xscale('log')
        plt.yscale('log')
    plt.tight_layout()
    if savefig: 
        try:
            date = datetime.now()
            file_date = f'({str(date.month)}-{str(date.day)}-{str(date.year)})'
            path_name = f'{main_title}_{file_date}.pdf'
            plt.savefig(os.path.join(os.getcwd(), f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', path_name), 
                        bbox_inches = 'tight', pad_inches = 0.3)
        except FileNotFoundError:
            os.makedirs(f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', exist_ok = True)
            plt.savefig(os.path.join(os.getcwd(), f'plots//({str(date.month)}-{str(date.day)}-{str(date.year)})', path_name),
                        bbox_inches = 'tight', pad_inches = 0.3)
            plt.close()
    else: 
        plt.show()

# %%
slope_median('Slope for Original Smooth Function Against Median Value', mean_v1_sorted, var_v1_sorted, logspace = False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 slope_median('Slope for Original Smooth Function Against Median Value', mean_v1_sorted, var_v1_sorted, logspace = False)
#
# Cell In[25], line 33, in slope_median(main_title, mean_masked, var_masked, savefig, logspace, x_val)
#      30 x_nonan = mean_masked[..., neuron][mask]
#      31 y_nonan = var_masked[..., neuron][mask]
# ---> 33 params, covariance = curve_fit(smooth_func, x_nonan, y_nonan, maxfev = 1_000_000, p0 = [1, .001])
#      35 # calculate slope at specified x_value
#      36 slope = func_prime.subs({x: x_val, m: params[0], b: params[1]})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\optimize\_minpack_py.py:1024, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1022 popt, pcov, infodict, errmsg, ier = res
#    1023 ysize = len(infodict['fvec'])
# -> 1024 cost = np.sum(infodict['fvec'] ** 2)
#    1025 if ier not in [1, 2, 3, 4]:
#    1026     raise RuntimeError("Optimal parameters not found: " + errmsg)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\fromnumeric.py:2250, in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2180     """
#    2181     Clip (limit) the values in an array.
#    2182
#    (...)
#    2245
#    2246     """
#    2247     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# -> 2250 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2251                     initial=None, where=None):
#    2252     return (a, out)
#    2255 @array_function_dispatch(_sum_dispatcher)
#    2256 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2257         initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:

# %%
x_val = 100

# %%
# define function
x, m, b = symbols('x m b')
func_expr = (m / b) * (sympy.log(1 + sympy.exp(b * x)) - sympy.log(2) - (b * x) / 2) # change function?
func_prime = diff(func_expr, x)

# %%
medians = []
slopes = []
for neuron in range(mean_v1_sorted.shape[1]):
        mask = ~np.isnan(mean_v1_sorted[..., neuron])
        x_nonan = mean_v1_sorted[..., neuron][mask]
        y_nonan = var_v1_sorted[..., neuron][mask]

        params, covariance = curve_fit(smooth_func, x_nonan, y_nonan, maxfev = 1_000_000, p0 = [1, .001])

        # calculate slope at specified x_value
        slope = func_prime.subs({x: x_val, m: params[0], b: params[1]})

        medians.append(np.median(x_nonan))
        slopes.append(slope)

# %%
fig, axs = plt.subplots()
medians = np.array(medians, dtype = np.float64)
slopes = np.array(slopes, dtype = np.float64)
m, b = np.polyfit(medians, slopes, 1)

plt.text(x = 0.05, y = .95, s = f'm={m:.3f}\nb={b:.3f}', ha = 'left', va = 'top', transform = axs.transAxes, )
plt.scatter(medians, slopes, marker = '.', alpha = 0.1)
plt.plot(medians, medians * m + b, color = 'r', linestyle = '--', label = 'regression')
plt.legend()
plt.title('Median Response Against Slope Regression')
plt.xlabel('medians')
plt.ylabel('slope')
plt.show()

# %%
fig, axs = plt.subplots()
medians = np.array(medians, dtype = np.float64)
slopes = np.array(slopes, dtype = np.float64)
m, b = np.polyfit(medians, slopes, 1)

plt.text(x = 0.05, y = .95, s = f'm={m:.3f}\nb={b:.3f}', ha = 'left', va = 'top', transform = axs.transAxes, )
plt.scatter(medians, slopes, marker = '.', alpha = 0.1)
plt.plot(medians, medians * m + b, color = 'r', linestyle = '--', label = 'regression')
plt.xlim(0, 35) # adjust xlim accordingly
plt.legend()
plt.title('Median Response Against Slope Regression\nCut at x=35')
plt.xlabel('medians')
plt.ylabel('slope')
plt.show()

# %%
fig, axs = plt.subplots()
medians = np.array(medians, dtype = np.float64)
slopes = np.array(slopes, dtype = np.float64)
m, b = np.polyfit(medians, slopes, 1)

plt.text(x = 0.05, y = .95, s = f'regression parameters:\nm={m:.3f}\nb={b:.3f}', ha = 'left', va = 'top', transform = axs.transAxes, )
plt.scatter(medians, slopes, marker = '.', alpha = 0.1)
plt.plot(medians, medians * m + b, color = 'r', linestyle = '--', label = 'regression')
plt.xlim(0, 50) # adjust xlim accordingly
plt.legend()
plt.title('Median Response Against Slope\nCut at x=50')
plt.xlabel('median')
plt.ylabel('slope')
plt.show()
