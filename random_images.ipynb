# %%
import os
from PIL import Image
import numpy as np
import pandas as pd

# %%
print(os.listdir())
# Out:
# TEST

# %%
path_imagenet = 'C://Users//joshf//downloads//imagenet-mini'

# %%
import subprocess
subprocess.run()

# %%
os.listdir(path_imagenet)
# Out:
# ['train', 'val']

# %%
path_imagenet = path_imagenet + '//train'

# %%
visited_dir1 = [dir_i for dir_i in os.listdir(path_imagenet)]

# %%
len(visited_dir1)
# Out:
# 1000

# %%
visited_dir1[0]
# Out:
# 'n01440764'

# %%
os.listdir(path_imagenet + '//' + visited_dir1[0])
# Out:
# ['n01440764_10043.JPEG',
#  'n01440764_10470.JPEG',
#  'n01440764_10744.JPEG',
#  'n01440764_10845.JPEG',
#  'n01440764_11170.JPEG',
#  'n01440764_12021.JPEG',
#  'n01440764_12063.JPEG',
#  'n01440764_12090.JPEG',
#  'n01440764_12329.JPEG',
#  'n01440764_12435.JPEG',
#  'n01440764_12534.JPEG',
#  'n01440764_13545.JPEG',
#  'n01440764_14411.JPEG',
#  'n01440764_14448.JPEG',
#  'n01440764_14731.JPEG',
#  'n01440764_15071.JPEG',
#  'n01440764_15560.JPEG',
#  'n01440764_1775.JPEG',
#  'n01440764_31518.JPEG',
#  'n01440764_3236.JPEG',
#  'n01440764_3603.JPEG',
#  'n01440764_4397.JPEG',
#  'n01440764_4852.JPEG',
#  'n01440764_4965.JPEG',
#  'n01440764_4979.JPEG',
#  'n01440764_5087.JPEG',
#  'n01440764_5376.JPEG',
#  'n01440764_5638.JPEG',
#  'n01440764_5785.JPEG',
#  'n01440764_6206.JPEG',
#  'n01440764_6425.JPEG',
#  'n01440764_8710.JPEG',
#  'n01440764_9157.JPEG',
#  'n01440764_9779.JPEG']

# %%
len(os.listdir(path_imagenet + '//' + visited_dir1[999]))
# Out:
# 38

# %% [markdown]
# return_stack = (shape = (n, 144, 256)) # stack of n objects
#
# return_df = DataFrame(columns = ['Folder ID', 'Photo ID'])
#
# for folder_id, folder in enumerate(imagenet) (n=1000)
#     for each subfolder in folder (n =? 30)
